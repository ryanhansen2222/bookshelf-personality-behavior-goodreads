# %% [markdown]
# # Calculate Basic Statistics of Detailed Reviews

# %%
# %pip install numpy pandas
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (1.24.4)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gzip
import json
import re
import os
import sys
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:,}'.format

# %% [markdown]
# **Specify your directory here:**

# %%
DIR = "/Users/natalie/Documents/Personal/Computing Courses/Social Computing - CS 6965/Final Project/Goodreads Data"
goodreads_data = DIR + "goodreads_reviews_dedup.json"
DIR_GENRE = goodreads_data
print("Files in DIR:", os.listdir(DIR))
# Out:
# Files in DIR: ['.DS_Store', 'goodreads_reviews_dedup.json', 'goodreads_books.json', 'reviews.ipynb', 'Archived']

# %% [markdown]
# **Calculate statistics of book reviews (without spoiler tags)**

# %%
# %pip install tqdm ipywidgets
import json
from tqdm.auto import tqdm

def count_reviews(file_name):
    book_set, user_set = set(), set()

    print('counting file:', file_name)
    n_review = 0
    book_set, user_set = set(), set()
    print('current line: ', end='')
    with open(file_name) as fin:
        for l in tqdm(fin, desc="Processing Reviews"):
            d = json.loads(l)
            if n_review % 1000000 == 0:
                print(n_review, end=',')
            n_review += 1
            book_set.add(d['book_id'])
            user_set.add(d['user_id'])
    print('complete')
    print('done!')
    return n_review, len(book_set), len(user_set)
# Out:
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (4.67.3)
# Requirement already satisfied: ipywidgets in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipywidgets) (8.12.3)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: backcall in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pickleshare in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack-data in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (4.13.2)
# Requirement already satisfied: pexpect>4.3 in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: appnope in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/natalie/Library/Python/3.8/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
n_review, n_book, n_user = count_reviews(os.path.join(DIR, 'goodreads_reviews_dedup.json'))
df_stats_review = pd.DataFrame([n_review, n_book, n_user], dtype=float,
                               columns=['count'], index=['# review', '# book', '# user'])
display(df_stats_review)
# Out:
# counting file: /Users/natalie/Documents/Personal/Computing Courses/Social Computing - CS 6965/Final Project/Goodreads Data/goodreads_reviews_dedup.json
# current line:
# Processing Reviews: 0it [00:00, ?it/s]
# 0,1000000,2000000,3000000,4000000,5000000,6000000,7000000,8000000,9000000,10000000,11000000,12000000,13000000,14000000,15000000,complete
# done!
#                 count
# # review 15,739,967.0
# # book    2,080,190.0
# # user      465,323.0

# %% [markdown]
# **Calculate statistics of the review subset with spoiler tags**

# %%
def count_spoilers(file_name):
    print('counting file:', file_name)
    n_review, n_sentence, n_spoiler_review, n_spoiler_sentence = 0, 0, 0, 0
    book_set, user_set = set(), set()
    print('current line: ', end='')
    with open(file_name) as fin:
        for l in fin:
            d = json.loads(l)
            if n_review % 1000000 == 0:
                print(n_review, end=',')
            n_review += 1
            for _t, _ in d['review_sentences']:
                n_sentence += 1
                n_spoiler_sentence += _t
            n_spoiler_review += int(d['has_spoiler'])
            book_set.add(d['book_id'])
            user_set.add(d['user_id'])
    print('complete')
    print('done!')
    return n_review, n_sentence, n_spoiler_review, n_spoiler_sentence, len(book_set), len(user_set)

# %%
res = count_spoilers(os.path.join(DIR, 'goodreads_reviews_spoiler.json'))
df_stats_spoiler = pd.DataFrame(res, columns=['count'], dtype=float, 
                               index=['# review', '# sentence', '# spoiler review', '# spoiler sentence',
                                      '# book', '# user'])
display(df_stats_spoiler)
# Out:
# counting file: /Users/natalie/Documents/Personal/Computing Courses/Social Computing - CS 6965/Final Project/Goodreads Data/goodreads_reviews_spoiler.json
# current line: 0,1000000,complete
# done!
#                           count
# # review            1,378,033.0
# # sentence         17,672,655.0
# # spoiler review       89,627.0
# # spoiler sentence    569,724.0
# # book                 25,475.0
# # user                 18,892.0

# %% [markdown]
# **Calculate basic statistics of review files for each genre:**

# %%
genre_list = ['children', 'comics_graphic', 'fantasy_paranormal', 'history_biography',
              'mystery_thriller_crime', 'poetry', 'romance', 'young_adult']

def count_all_genres(genre_list):
    res = []
    for g in genre_list:
        n_review, n_book, n_user = count_reviews(
            os.path.join(DIR_GENRE, 'goodreads_reviews_'+g+'.json.gz'))
        res.append([n_review, n_book, n_user])
    df_stats_by_genre = pd.DataFrame(res, dtype = float, 
                                     columns = ['# review', '# book', '# user'],
                                     index = genre_list)
    return df_stats_by_genre

# %%
df_stats_by_genre = count_all_genres(genre_list)
display(df_stats_by_genre)
# Out:
# counting file: ./genre/goodreads_reviews_children.json.gz
# current line: 0,complete
# done!
# counting file: ./genre/goodreads_reviews_comics_graphic.json.gz
# current line: 0,complete
# done!
# counting file: ./genre/goodreads_reviews_fantasy_paranormal.json.gz
# current line: 0,1000000,2000000,3000000,complete
# done!
# counting file: ./genre/goodreads_reviews_history_biography.json.gz
# current line: 0,1000000,2000000,complete
# done!
# counting file: ./genre/goodreads_reviews_mystery_thriller_crime.json.gz
# current line: 0,1000000,complete
# done!
# counting file: ./genre/goodreads_reviews_poetry.json.gz
# current line: 0,complete
# done!
# counting file: ./genre/goodreads_reviews_romance.json.gz
# current line: 0,1000000,2000000,3000000,complete
# done!
# counting file: ./genre/goodreads_reviews_young_adult.json.gz
# current line: 0,1000000,2000000,complete
# done!
#                           # review    # book    # user
# children                 734,640.0 123,946.0  92,667.0
# comics_graphic           542,338.0  89,311.0  59,347.0
# fantasy_paranormal     3,424,641.0 258,212.0 256,088.0
# history_biography      2,066,193.0 302,346.0 238,450.0
# mystery_thriller_crime 1,849,236.0 218,987.0 203,655.0
# poetry                   154,555.0  36,412.0  47,400.0
# romance                3,565,378.0 334,957.0 198,141.0
# young_adult            2,389,900.0  93,267.0 209,152.0
